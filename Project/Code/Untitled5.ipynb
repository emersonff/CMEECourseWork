# %%
import json
import pandas as pd #'1.0.4'
import numpy as np
import os
import seaborn as sn
import matplotlib.pyplot as plt
#import Json
#from pandas_ml import ConfusionMatrix

# %%
d = pd.read_csv("../Data/SkeletonCount.csv")

# %%
d.insert(0, "Folder", d.SourceFile.str.extract(r'(\d+_.*)IMG'))

# %%
a = d.loc[d['h'] == 19].Folder.unique()[5]
a
# Out:
# '101_HH_11_5_18100_BTCF100_BTCF/'

# %%
[3]
# Out:
# [1, 3]

# %%
#d.loc[d["Folder"] == a][0]

# %%
d.loc[(d['h'] == 19) & (d["Folder"] == a )].SourceFile.unique()
# Out:
# array(['101_HH_11_5_18100_BTCF100_BTCF/IMG_1109.JPG',
#        '101_HH_11_5_18100_BTCF100_BTCF/IMG_2558.JPG',
#        '101_HH_11_5_18100_BTCF100_BTCF/IMG_1572.JPG',
#        '101_HH_11_5_18100_BTCF100_BTCF/IMG_1765.JPG',
#        '101_HH_11_5_18100_BTCF100_BTCF/IMG_1103.JPG',
#        '101_HH_11_5_18100_BTCF100_BTCF/IMG_1113.JPG',
#        '101_HH_11_5_18100_BTCF100_BTCF/IMG_1558.JPG',
#        '101_HH_11_5_18100_BTCF100_BTCF/IMG_1111.JPG',
#        '101_HH_11_5_18100_BTCF100_BTCF/IMG_1112.JPG',
#        '101_HH_11_5_18100_BTCF100_BTCF/IMG_1561.JPG',
#        '101_HH_11_5_18100_BTCF100_BTCF/IMG_0403.JPG',
#        '101_HH_11_5_18100_BTCF100_BTCF/IMG_0401.JPG',
#        '101_HH_11_5_18100_BTCF100_BTCF/IMG_0396.JPG',
#        '101_HH_11_5_18100_BTCF100_BTCF/IMG_1573.JPG',
#        '101_HH_11_5_18100_BTCF100_BTCF/IMG_0391.JPG',
#        '101_HH_11_5_18100_BTCF100_BTCF/IMG_0389.JPG',
#        '101_HH_11_5_18100_BTCF100_BTCF/IMG_0393.JPG',
# ...

# %%
[1, 3]

# %%
d.loc[(d['h'] < 6) & (d["Folder"] == a )]
# Out:
#                    Folder                      SourceFile  Count  \
# 235    19_HH_1_5_18_DCIM/  19_HH_1_5_18_DCIM/IMG_2252.JPG      1
# 1240   19_HH_1_5_18_DCIM/  19_HH_1_5_18_DCIM/IMG_2234.JPG      1
# 2684   19_HH_1_5_18_DCIM/  19_HH_1_5_18_DCIM/IMG_2236.JPG      1
# 2886   19_HH_1_5_18_DCIM/  19_HH_1_5_18_DCIM/IMG_0979.JPG      1
# 5096   19_HH_1_5_18_DCIM/  19_HH_1_5_18_DCIM/IMG_0975.JPG      1
# 5285   19_HH_1_5_18_DCIM/  19_HH_1_5_18_DCIM/IMG_2022.JPG      1
# 8444   19_HH_1_5_18_DCIM/  19_HH_1_5_18_DCIM/IMG_3003.JPG      1
# 10141  19_HH_1_5_18_DCIM/  19_HH_1_5_18_DCIM/IMG_0977.JPG      1
# 10443  19_HH_1_5_18_DCIM/  19_HH_1_5_18_DCIM/IMG_2233.JPG      1
# 11564  19_HH_1_5_18_DCIM/  19_HH_1_5_18_DCIM/IMG_2240.JPG      1
# 11683  19_HH_1_5_18_DCIM/  19_HH_1_5_18_DCIM/IMG_2986.JPG      1
# 13751  19_HH_1_5_18_DCIM/  19_HH_1_5_18_DCIM/IMG_3008.JPG      1
# 14293  19_HH_1_5_18_DCIM/  19_HH_1_5_18_DCIM/IMG_0965.JPG      1
# ...

# %%
d.loc[(d['h'] < 6) & (d["Folder"] == a )].CreateDate.str.extract(r"\s(\d{2}):")

# %%
np.arccos(0.5)
# Out:
# 1.0471975511965979
